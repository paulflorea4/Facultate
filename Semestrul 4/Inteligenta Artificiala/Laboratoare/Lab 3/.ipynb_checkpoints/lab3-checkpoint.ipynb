# %%
pip install azure-cognitiveservices-vision-computervision
# Out:
# Collecting azure-cognitiveservices-vision-computervision
#   Downloading azure_cognitiveservices_vision_computervision-0.9.1-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting msrest>=0.6.21 (from azure-cognitiveservices-vision-computervision)
#   Downloading msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# Collecting azure-common~=1.1 (from azure-cognitiveservices-vision-computervision)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting azure-core>=1.24.0 (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision)
#   Downloading azure_core-1.38.2-py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\paulf\AppData\Local\Programs\Python\Python314\Lib\site-packages (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (2025.10.5)
# Collecting isodate>=0.6.0 (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting requests-oauthlib>=0.5.0 (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests~=2.16 in C:\Users\paulf\AppData\Local\Programs\Python\Python314\Lib\site-packages (from msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\paulf\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests~=2.16->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\paulf\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests~=2.16->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\paulf\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests~=2.16->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (2.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\paulf\AppData\Local\Programs\Python\Python314\Lib\site-packages (from azure-core>=1.24.0->msrest>=0.6.21->azure-cognitiveservices-vision-computervision) (4.15.0)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-cognitiveservices-vision-computervision)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading azure_cognitiveservices_vision_computervision-0.9.1-py2.py3-none-any.whl (36 kB)
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
# Downloading azure_core-1.38.2-py3-none-any.whl (217 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: azure-common, oauthlib, isodate, requests-oauthlib, azure-core, msrest, azure-cognitiveservices-vision-computervision
#
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----- ---------------------------------- 1/7 [oauthlib]
#    ----------- ---------------------------- 2/7 [isodate]
#    ----------------- ---------------------- 3/7 [requests-oauthlib]
#    ----------------- ---------------------- 3/7 [requests-oauthlib]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------- ----------------- 4/7 [azure-core]
#    ---------------------------- ----------- 5/7 [msrest]
#    ---------------------------- ----------- 5/7 [msrest]
#    ---------------------------- ----------- 5/7 [msrest]
#    -------------------- --- 6/7 [azure-cognitiveservices-vision-computervision]
#    -------------------- --- 6/7 [azure-cognitiveservices-vision-computervision]
#    ------------------------ 7/7 [azure-cognitiveservices-vision-computervision]
#
# Successfully installed azure-cognitiveservices-vision-computervision-0.9.1 azure-common-1.1.28 azure-core-1.38.2 isodate-0.7.2 msrest-0.7.1 oauthlib-3.3.1 requests-oauthlib-2.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in C:\Users\paulf\AppData\Local\Programs\Python\Python314\Lib\site-packages (12.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials
from array import array
import os
from PIL import Image
import sys
import time

# %%
'''
Authenticate
Authenticates your credentials and creates a client.
'''
subscription_key = os.environ["VISION_KEY"]
endpoint = os.environ["VISION_ENDPOINT"]
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))
'''
END - Authenticate
'''
# Out:
# '\nEND - Authenticate\n'

# %%
#img = open("test1.png", "rb")
img = open("download.jpg", "rb")
read_response = computervision_client.read_in_stream(
    image=img,
    mode="Printed",
    raw=True
)
# print(read_response.as_dict())

operation_id = read_response.headers['Operation-Location'].split('/')[-1]
while True:
    read_result = computervision_client.get_read_result(operation_id)
    if read_result.status not in ['notStarted', 'running']:
        break
    time.sleep(1)

# Print the detected text, line by line
result = []
if read_result.status == OperationStatusCodes.succeeded:
    for text_result in read_result.analyze_result.read_results:
        for line in text_result.lines:
            print(line.text)
            result.append(line.text)

print()
# Out:
# My handmade
# Some people say that my hood
# write is ugly. They say then
# Can't qwant how I vale slow
# words, self- confidence takes a
# hut. I'mworking ina office
# where pappers work exist
# there handwriteis required
# sometimes. Writing stylecanbe
# difficult to read of times, I
# know. But it is nice for the hard
# and arm, I think. Writing by-
# hand is to be the muscle of
# memory. It's easier ture
# ber what you learn If I webs
# while writing it will be like
# nous

# %%
# get/define the ground truth
# groundTruth = ["Google Cloud", "Platform"]
groundTruth = ["Succes in rezolvarea", "tEMELOR la", "LABORAtoaree de", "Inteligenta Artificiala!"]

# compute the performance
noOfCorrectLines = sum(i == j for i, j in zip(result, groundTruth))
print(noOfCorrectLines)
# Out:
# 0
